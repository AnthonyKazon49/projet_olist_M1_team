# %% [markdown]
# **Exploration des données**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
customers= pd.read_csv('olist_customers_dataset.csv')
geolocalisation= pd.read_csv('olist_geolocation_dataset.csv')
order_items= pd.read_csv('olist_order_items_dataset.csv')
order_payements= pd.read_csv('olist_order_payments_dataset.csv')
order_reviews= pd.read_csv('olist_order_reviews_dataset.csv')
orders= pd.read_csv('olist_orders_dataset.csv')
products= pd.read_csv('olist_products_dataset.csv')
sellers= pd.read_csv('olist_sellers_dataset.csv')
name_translation= pd.read_csv('product_category_name_translation.csv')

# %%
products = products.merge(name_translation, on='product_category_name', how='left')

# %%
print(products[['product_category_name', 'product_category_name_english']].head())
# Out:
#    product_category_name product_category_name_english
# 0             perfumaria                     perfumery
# 1                  artes                           art
# 2          esporte_lazer                sports_leisure
# 3                  bebes                          baby
# 4  utilidades_domesticas                    housewares

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
name_translation
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]
# No charts were generated by quickchart

# %%
order_payements
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
order_payements['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
def autopct_format(pct, all_labels):
  return f"{pct:.1f}%" if pct >= 1 else ""  # Cache les pourcentages < 1%
labels=order_payements.payment_type.value_counts().index
plt.pie(order_payements.payment_type.value_counts(),labels=labels, autopct=lambda pct: autopct_format(pct, labels),)
plt.title('Répartition des types de paiement')
plt.show()

# %%
order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# ***Quel produit est le plus vendu?***

# %%
# Fusionner les données des commandes et des articles de commande
merged_data = order_items.merge(products, on='product_id')

# %%
merged_data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# Compter le nombre de ventes par produit
product_sales = merged_data['product_id'].value_counts().reset_index()
product_sales.columns = ['product_id', 'sales_count']

# %%
product_sales
# Out:
#                              product_id  sales_count
# 0      aca2eb7d00ea1a7b8ebd4e68314663af          527
# 1      99a4788cb24856965c36a24e339b6058          488
# 2      422879e10f46682990de24d770e7f83d          484
# 3      389d119b48cf3043d311335e499d9c6b          392
# 4      368c6c730842d78016ad823897a372db          388
# ...                                 ...          ...
# 32946  dbc42f8ad8afd0147a5a46be630781f8            1
# 32947  5d86ed92606c80a89e547cdba3946812            1
# 32948  0b8750fa58fefe42cf03a9e2e4b8fce6            1
# 32949  a4758e74e2cdb74d0c4db83594ca14a3            1
# 32950  350688d9dc1e75ff97be326363655e01            1
#
# [32951 rows x 2 columns]

# %%
# Trouver le produit le plus vendu
most_sold_product = product_sales.iloc[0]
most_sold_product
# Out:
# product_id     aca2eb7d00ea1a7b8ebd4e68314663af
# sales_count                                 527
# Name: 0, dtype: object

# %%
#trouver la catégorie du produit le plus vendu :
product_id_most_sold = 'aca2eb7d00ea1a7b8ebd4e68314663af'
#filtrer la table produit pour obtenir la catégorie
product_info = products[products['product_id'] == product_id_most_sold]
#récupérer le nom de la catégorie
product_category = product_info['product_category_name_english'].values[0]
product_category
# Out:
# 'furniture_decor'

# %% [markdown]
# ***Quelles sont catégorie de produit qui génère le plus ventes?***

# %%
#Compter le nombre de vente par catégorie
category_sales = merged_data.groupby('product_category_name')['product_id'].count().reset_index()
category_sales.columns=['category', 'sales_count']

# %%
category_sales
# Out:
#                      category  sales_count
# 0   agro_industria_e_comercio          212
# 1                   alimentos          510
# 2           alimentos_bebidas          278
# 3                       artes          209
# 4          artes_e_artesanato           24
# ..                        ...          ...
# 68    sinalizacao_e_seguranca          199
# 69   tablets_impressao_imagem           83
# 70                  telefonia         4545
# 71             telefonia_fixa          264
# 72      utilidades_domesticas         6964
#
# [73 rows x 2 columns]

# %%
most_sold_category = category_sales.sort_values(by='sales_count', ascending=False).iloc[0]
most_sold_category
# Out:
# category       cama_mesa_banho
# sales_count              11115
# Name: 13, dtype: object

# %%
#Toute catégorie
plt.figure(figsize=(10,14))
sns.barplot(x='sales_count', y='category', data=category_sales.sort_values(by='sales_count', ascending=False))
plt.title('Ventes par catégorie de produit')
plt.xlabel('Nombre de ventes')
plt.ylabel('Catégorie de produit')
plt.show()

# %%
#top 5 des catégorie max vente
plt.figure(figsize=(6,4))
sns.barplot(x='sales_count', y='category', data=category_sales.sort_values(by='sales_count', ascending=False).head())
plt.title('Ventes par catégorie de produit')
plt.xlabel('Nombre de ventes')
plt.ylabel('Catégorie de produit')
plt.show()

# %% [markdown]
# ***Quelles est le chiffres d'affaire par produit ?***

# %%
# Calculer le chiffre d'affaires par produit
merged_data['revenue'] = merged_data['price']  # Chaque ligne représente une vente, donc le prix est le chiffre d'affaires pour cette vente
revenue_per_product = merged_data.groupby('product_id')['revenue'].sum().reset_index()

# %%
revenue_per_product
# Out:
#                              product_id   revenue
# 24086  bb50f2e236e5eea0100680137654686c  63885.00
# 14068  6cdd53843498f92890544667809f1595  54730.20
# 27613  d6160fb7873f184099d9bc95e30376af  48899.34
# 27039  d1c427060a0f73f6b889a5c7c61f2ac4  47214.51
# 19742  99a4788cb24856965c36a24e339b6058  43025.56
# ...                                 ...       ...
# 6086   2e8316b31db34314f393806fd7b6e185      2.99
# 13461  680cc8535be7cc69544238c1d6a83fe8      2.90
# 17767  8a3254bee785a526d548a81a9bc3c9be      2.55
# 6388   310dc32058903b6416c71faff132df9e      2.29
# 9238   46fce52cef5caa7cc225a5531c946c8b      2.20
#
# [32951 rows x 2 columns]
# ...

# %%
# Trier par chiffre d'affaires - le produit qui à généré le plus de $
revenue_per_product = revenue_per_product.sort_values(by='revenue', ascending=False)
top_revenue_product = revenue_per_product.iloc[0]
top_revenue_product
# Out:
# product_id    bb50f2e236e5eea0100680137654686c
# revenue                                63885.0
# Name: 24086, dtype: object

# %%
# Produit à analyser
product_id_top_revenue = 'bb50f2e236e5eea0100680137654686c'

# Filtrer les ventes du produit dans 'order_items'
product_sales = order_items[order_items['product_id'] == product_id_top_revenue]

# Fusionner avec la table 'orders' pour obtenir la date d'achat
product_sales = product_sales.merge(orders[['order_id', 'order_purchase_timestamp']], on='order_id', how='left')

# Convertir la colonne en format datetime
product_sales['order_purchase_timestamp'] = pd.to_datetime(product_sales['order_purchase_timestamp'])

# Additioner les ventes par mois et calculer le chiffre d'affaires
product_sales['month'] = product_sales['order_purchase_timestamp'].dt.to_period('M')  # Regroupement par mois
monthly_revenue = product_sales.groupby('month')['price'].sum().reset_index()

# Convertir en datetime pour l'affichage sur le graphique
monthly_revenue['month'] = monthly_revenue['month'].astype(str)  # Convertir en char pour éviter les erreurs

# Tracer le graphique
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_revenue, x='month', y='price', marker='o')

# Paramêtre du graphique
plt.title(f"Évolution du chiffre d'affaires du produit {product_id_top_revenue} de 08-2017 à 08-2028", fontsize=11)
plt.xlabel("Période (mois)", fontsize=12)
plt.ylabel("Chiffre d'affaires (BRL)", fontsize=12)
plt.xticks(rotation=45)  # Incliner les dates pour une meilleure lisibilité
plt.grid(True)

# Afficher le graphique
plt.show()

# %%
merged_data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# Regrouper par catégorie et sommer le chiffre d'affaires
category_revenue = merged_data.groupby('product_category_name')['revenue'].sum().reset_index()
category_revenue.columns = ['category', 'total_revenue']

# %%
category_revenue = category_revenue.sort_values(by='total_revenue', ascending=False)
category_revenue
# Out:
#                          category  total_revenue
# 11                   beleza_saude     1258681.34
# 66             relogios_presentes     1205005.68
# 13                cama_mesa_banho     1036988.68
# 32                  esporte_lazer      988048.97
# 44         informatica_acessorios      911954.32
# ..                            ...            ...
# 41                         flores        1110.04
# 15                casa_conforto_2         760.27
# 17              cds_dvds_musicais         730.00
# 37  fashion_roupa_infanto_juvenil         569.85
# 67             seguros_e_servicos         283.29
#
# [73 rows x 2 columns]

# %%
#Top 5
category_revenue = category_revenue.sort_values(by='total_revenue', ascending=False).head(5)
category_revenue
# Out:
#                   category  total_revenue
# 11            beleza_saude     1258681.34
# 66      relogios_presentes     1205005.68
# 13         cama_mesa_banho     1036988.68
# 32           esporte_lazer      988048.97
# 44  informatica_acessorios      911954.32

# %%
import matplotlib.ticker as ticker

# %%
# Fonction de formatage pour l'axe des y
def formatter_func(value, tick_number):
    return f"{int(value * 100000)}"

# %%
colors=['blue', 'orange', 'green', 'red', 'purple']

# %%
# histogramme
plt.figure(figsize=(5, 4))
plt.bar(category_revenue['category'], category_revenue['total_revenue'], color=colors, edgecolor='black')
plt.title('Top 5 des catégories par chiffre d\'affaires en Millions')
plt.xlabel('Catégories')
plt.ylabel('Chiffre d\'affaires')
plt.xticks(rotation=45)
plt.show()
